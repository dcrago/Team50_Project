# %%
import json
import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy

# %%
testing_sites_df =  pd.read_csv('https://raw.githubusercontent.com/dcrago/Team50_Project/main/COVID-19%20Testing%20Locations%20Symbolized%20by%20Test%20Type.csv?token=AP7Z5UVL5AEH4YLZOKSZXFS73OAGM')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-104-27c39d396a53> in <module>
# ----> 1 testing_sites_df =  pd.read_csv('https://raw.githubusercontent.com/dcrago/Team50_Project/main/COVID-19%20Testing%20Locations%20Symbolized%20by%20Test%20Type.csv?token=AP7Z5UVL5AEH4YLZOKSZXFS73OAGM')
#
# ~/.local/lib/python3.6/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# ~/.local/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     435     # See https://github.com/python/mypy/issues/1297
#     436     fp_or_buf, _, compression, should_close = get_filepath_or_buffer(
# --> 437         filepath_or_buffer, encoding, compression
#     438     )
#     439     kwds["compression"] = compression
#
# ~/.local/lib/python3.6/site-packages/pandas/io/common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     181     if isinstance(filepath_or_buffer, str) and is_url(filepath_or_buffer):
#     182         # TODO: fsspec can also handle HTTP via requests, but leaving this unchanged
# --> 183         req = urlopen(filepath_or_buffer)
#     184         content_encoding = req.headers.get("Content-Encoding", None)
#     185         if content_encoding == "gzip":
#
# ~/.local/lib/python3.6/site-packages/pandas/io/common.py in urlopen(*args, **kwargs)
#     135     import urllib.request
#     136
# --> 137     return urllib.request.urlopen(*args, **kwargs)
#     138
#     139
#
# /opt/conda/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# /opt/conda/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# /opt/conda/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# /opt/conda/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     568         if http_err:
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#     572 # XXX probably also want an abstract factory that knows when it makes
#
# /opt/conda/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /opt/conda/lib/python3.6/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648 class HTTPDefaultErrorHandler(BaseHandler):
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#     652 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %%
testing_sites_df.drop(columns = ['Owner Name','Phone','Website','Operational Hours','Vehicle Capacity','CreationDate','Drive-through','Appointment Only','Referral Required','Call first','Virtual/Telehealth Screening','Local Health Department URL','Vehicle Required','Offering same-day diagnostic (not antibody) results','Offering Take-Home Test','Status Color'], inplace = True)
testing_sites_df.drop(columns = ['Public Form Submission','Minimum Age','Wheelchair accessibility ','Accessibility Support'], inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-98-1d16afc54b38> in <module>
# ----> 1 testing_sites_df.drop(columns = ['Owner Name','Phone','Website','Operational Hours','Vehicle Capacity','CreationDate','Drive-through','Appointment Only','Referral Required','Call first','Virtual/Telehealth Screening','Local Health Department URL','Vehicle Required','Offering same-day diagnostic (not antibody) results','Offering Take-Home Test','Status Color'], inplace = True)
#       2 testing_sites_df.drop(columns = ['Public Form Submission','Minimum Age','Wheelchair accessibility ','Accessibility Support'], inplace = True)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3921                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3922             else:
# -> 3923                 new_axis = axis.drop(labels, errors=errors)
#    3924             result = self.reindex(**{axis_name: new_axis})
#    3925
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5285         if mask.any():
#    5286             if errors != "ignore":
# -> 5287                 raise KeyError(f"{labels[mask]} not found in axis")
#    5288             indexer = indexer[~mask]
#    5289         return self.delete(indexer)
#
# KeyError: "['Owner Name' 'Phone' 'Website' 'Operational Hours' 'Vehicle Capacity'\n 'CreationDate' 'Drive-through' 'Appointment Only' 'Referral Required'\n 'Call first' 'Virtual/Telehealth Screening' 'Local Health Department URL'\n 'Vehicle Required' 'Offering same-day diagnostic (not antibody) results'\n 'Offering Take-Home Test' 'Status Color'] not found in axis"

# %%
testing_sites_df.head()
# Out:
#                                     Name of Facility  \
# 0  Wheeling Hospital/WVU Hospitals Offsite COVID-...
# 1                          Middleton Family Medicine
# 2                   Central Outreach Wellness Center
# 3                      Anthony Wayne Recreation Area
# 4  Wexford Health + Wellness Pavilion (Allegheny ...
#
#                                         Full Address   Municipality  \
# 0  Wheeling Park (Near Ice Rink), 1801 National R...       Wheeling
# 1          147 South Main Street Middleton, MA 01949      Middleton
# 2  127 Anderson Street, Suite 101 Timber Court Bu...     Pittsburgh
# 3  Palisades Int Interstate Parkway, Exit 17, Bea...  Bear Mountain
# 4              12311 Perry Highway Wexford, PA 15090        Wexford
#
#         Owner Type  Daily Testing Capacity  \
# 0        Municipal                     NaN
# 1            Other                     NaN
# 2        Nonprofit                     NaN
# 3  State/Territory                     NaN
# 4          Private                     NaN
#
#                        Services Offered State or Territory     County  \
# 0  COVID-19 testing only (no screening)      West Virginia       Ohio
# 1  COVID-19 testing only (no screening)      Massachusetts      Essex
# 2        COVID-19 screening and testing       Pennsylvania  Allegheny
# 3  COVID-19 testing only (no screening)           New York     Orange
# 4  COVID-19 testing only (no screening)       Pennsylvania  Allegheny
#
#   Testing Start Date Testing End Date Kind of test  \
# 0                NaN              NaN    Molecular
# 1                NaN              NaN    Molecular
# 2                NaN              NaN    Molecular
# 3                NaN              NaN    Molecular
# 4                NaN              NaN    Molecular
#
#             Processing location         Facility Type            x  \
# 0  Lab (location not specified)              Hospital -8979782.297
# 1  Lab (location not specified)  Clinic/Health Center -7904519.958
# 2  Lab (location not specified)          Outdoor/Tent -8905649.968
# 3  Lab (location not specified)                   NaN -8240722.529
# 4  Lab (location not specified)  Clinic/Health Center -8912678.464
#
#              y
# 0  4874576.993
# 1  5248669.198
# 2  4931349.163
# 3  5056547.051
# 4  4958745.420

# %%
Covid_data = pd.read_csv("https://raw.githubusercontent.com/nytimes/covid-19-data/master/live/us-counties.csv")

# %%
asthma = pd.read_csv('500_Cities__Current_asthma_among_adults_aged___18_years.csv')

# %%
Covid_data
# Out:
#             date      county    state     fips  cases  deaths  \
# 0     2020-12-22     Autauga  Alabama   1001.0   3841    44.0
# 1     2020-12-22     Baldwin  Alabama   1003.0  12155   149.0
# 2     2020-12-22     Barbour  Alabama   1005.0   1363    32.0
# 3     2020-12-22        Bibb  Alabama   1007.0   1660    42.0
# 4     2020-12-22      Blount  Alabama   1009.0   4313    54.0
# ...          ...         ...      ...      ...    ...     ...
# 3240  2020-12-22  Sweetwater  Wyoming  56037.0   2780    15.0
# 3241  2020-12-22       Teton  Wyoming  56039.0   2033     2.0
# 3242  2020-12-22       Uinta  Wyoming  56041.0   1460     7.0
# 3243  2020-12-22    Washakie  Wyoming  56043.0    719    12.0
asthma['asthma_value_times_count']
# Out:
# 0         528.612
# 1        5524.416
# 2         478.986
# 3         359.048
# 4         244.664
#            ...
# 29001     403.506
# 29002      45.235
# 29003     135.013
# 29004     137.800
# 29005     363.792
# Name: asthma_value_times_count, Length: 29006, dtype: float64

# %%
asthma.head()
# Out:
#    Year StateAbbr StateDesc       CityName GeographicLevel DataSource  \
# 0  2017        GA   Georgia       Columbus    Census Tract      BRFSS
# 1  2017        GA   Georgia    Johns Creek            City      BRFSS
# 2  2017        GA   Georgia  Sandy Springs    Census Tract      BRFSS
# 3  2017        GA   Georgia        Roswell    Census Tract      BRFSS
# 4  2017        GA   Georgia       Savannah    Census Tract      BRFSS
#
#           Category             UniqueID  \
# 0  Health Outcomes  1319000-13215010302
# 1  Health Outcomes              1342425
# 2  Health Outcomes  1368516-13121010119
# 3  Health Outcomes  1367284-13121011423
# 4  Health Outcomes  1369000-13051002300
#
#                                        Measure Data_Value_Unit  ...  \
# 0  Current asthma among adults aged >=18 Years               %  ...
# 1  Current asthma among adults aged >=18 Years               %  ...
# 2  Current asthma among adults aged >=18 Years               %  ...
# 3  Current asthma among adults aged >=18 Years               %  ...
# 4  Current asthma among adults aged >=18 Years               %  ...
#
#   Data_Value_Footnote_Symbol Data_Value_Footnote  PopulationCount  \
# 0                        NaN                 NaN             6293
# 1                        NaN                 NaN            76728
# 2                        NaN                 NaN             4938
# 3                        NaN                 NaN             4852
# 4                        NaN                 NaN             2056
#
#                        GeoLocation  CategoryID MeasureId   CityFIPS  \
# 0   (32.5420961469, -84.975715442)     HLTHOUT   CASTHMA  1319000.0
# 1  (34.0332991998, -84.2027195506)     HLTHOUT   CASTHMA  1342425.0
# 2  (33.9913040108, -84.3452326148)     HLTHOUT   CASTHMA  1368516.0
# 3  (34.0177367078, -84.3840157981)     HLTHOUT   CASTHMA  1367284.0
# 4  (32.0577200508, -81.1112836355)     HLTHOUT   CASTHMA  1369000.0
#
#       TractFIPS Short_Question_Text    state
# 0  1.321501e+10      Current Asthma  Georgia
# 1           NaN      Current Asthma  Georgia
# 2  1.312101e+10      Current Asthma  Georgia
# 3  1.312101e+10      Current Asthma  Georgia
# 4  1.305100e+10      Current Asthma  Georgia
#
# [5 rows x 25 columns]

# %%
asthma1 = asthma.groupby(['state']).sum()
asthma_state_count = asthma1['asthma_value_times_count']

# %%
from IPython.display import HTML

# %%
census_insurance = pd.read_csv('https://www2.census.gov/programs-surveys/demo/datasets/income-poverty/time-series/data-extracts/2018/cps-asec-bridge-file/hhpub18.csv')
census_insurance.columns
#HCOV NOW_HCOV 
# HTML(filename='www.census.gov/data/tables/time-series/demo/health-insurance/historical-series/hib.html')
# Out:
# Index(['H_IDNUM', 'GEREG', 'GESTFIPS', 'GEDIV', 'HRHTYPE', 'HEFAMINC',
#        'H_MONTH', 'H_YEAR', 'H_TENURE', 'H_HHNUM',
#        ...
#        'THCHCARE_VAL', 'THPROP_VAL', 'GTCBSA', 'GTCO', 'GTCBSAST', 'GTCBSASZ',
# Georgia                  877.0
# Hawaii                     0.0
# Idaho                     36.0
# Illinois                1167.0
# Indiana                  337.0
# Iowa                       0.0
# Kansas                    25.0
# Kentucky                  12.0
# Louisiana                345.0
# Maine                      0.0
# Maryland                 166.0
# Massachusetts              0.0
# Michigan                 631.0
# Minnesota                  0.0
# Mississippi                0.0
# Missouri                   1.0
# Montana                    0.0
# Nebraska                   8.0
# Nevada                     0.0
# New Hampshire              0.0
# New Jersey              1908.0
# New Mexico                 0.0
# New York                4762.0
# North Carolin              NaN
# North Dakota               0.0
# Ohio                       0.0
# Oklahoma                   0.0
# Oregon                     0.0
# Pennsylvania             330.0
# Rhode Island             754.0
# South Carolin              NaN
# South Dakota               0.0
# Tennessee                169.0
# Texas                   5550.0
# United States              NaN
# Utah                     273.0
# Vermont                    0.0
# Virginia                   0.0
# Washington               352.0
# West Virginia            111.0
# Wisconsin                286.0
# Wyoming                    0.0

# %%
covid_asthma.corr()[['asthma_value_times_count', 'confirmed_deaths']]
# Out:
#                           asthma_value_times_count  confirmed_deaths
# asthma_value_times_count                  1.000000          0.756434
# fips                                      0.241457          0.153841
# cases                                     0.901716          0.806086
# deaths                                    0.764216          0.937176
# confirmed_cases                           0.871391          0.701451
# confirmed_deaths                          0.756434          1.000000
# probable_cases                            0.244837          0.242268
# probable_deaths                           0.463305          0.683223

# %%
with open('waqi-covid19-airqualitydata-2020.csv') as AQI:
    AQI = pd.read_csv(AQI)
AQI.head()
# Out:
#         Date Country      City Specie  count    min    max  median  variance
# 0  2/27/2020      UZ  Tashkent   pm25     24   34.0  147.0    53.0  10221.70
# 1  3/12/2020      UZ  Tashkent   pm25     24  152.0  201.0   160.0   1304.93
# 2   8/2/2020      UZ  Tashkent   pm25     24   38.0  119.0    63.0   4586.67
# 3  8/23/2020      UZ  Tashkent   pm25     24   55.0  159.0    74.0  10854.50
# 4  10/4/2020      UZ  Tashkent   pm25     24   70.0  157.0    85.0   5356.94

# %%
AQI.columns
# Out:
# Index(['Date', 'Country', 'City', 'Specie', 'count', 'min', 'max', 'median',
#        'variance'],
#       dtype='object')

# %%
AQI_US = AQI.loc[AQI['Country'] == 'US']
AQI_US
# Out:
#               Date Country           City Specie  count    min    max  median  \
# 508048  11/19/2020      US  Oklahoma City    so2      3    1.5    1.5     1.5
# 508049  11/26/2020      US  Oklahoma City    so2      3    1.5    1.5     1.5
# 508050   1/26/2020      US  Oklahoma City    so2      6    1.5    2.9     1.5
# 508051   2/26/2020      US  Oklahoma City    so2      2    1.5    1.5     1.5
# 508052   5/17/2020      US  Oklahoma City    so2      3    1.5    1.5     1.5
# ...            ...     ...            ...    ...    ...    ...    ...     ...
# 693444   9/27/2020      US     Fort Worth     wd     22  145.0  345.0   167.0
# 693445  10/18/2020      US     Fort Worth     wd     22  132.0  343.0   180.0
# 693446  10/22/2020      US     Fort Worth     wd     22  162.0  203.0   181.0
# 693447  10/25/2020      US     Fort Worth     wd     21   59.0  150.0   121.0
# 693448  11/22/2020      US     Fort Worth     wd     22    1.0  334.0    14.0
#
#         variance
# 508048      0.00
# 508049      0.00
# 508050      5.88
# 508051      0.00
# 508052      0.00
# ...          ...
# 693444  15960.40
# 693445  35425.30
# 693446   1041.41
# 693447  11861.60
# 693448  81433.20
#
# [185401 rows x 9 columns]

# %%
pd.unique(AQI_US['Specie'])
# Out:
# array(['so2', 'wind gust', 'wind-gust', 'temperature', 'wind-speed',
#        'pm10', 'pm25', 'no2', 'o3', 'pressure', 'dew', 'co', 'humidity',
#        'wind speed', 'wd', 'precipitation'], dtype=object)

# %%
#lists of countries and cities
print('countries', pd.unique(AQI['Country']))
print('cities', pd.unique(AQI['City']))
# Out:
# countries ['UZ' 'BE' 'BH' 'GB' 'KR' 'TM' 'AU' 'HK' 'NP' 'SG' 'DE' 'RO' 'UG' 'CA'
#  'KW' 'PE' 'GT' 'IN' 'PR' 'BG' 'CY' 'DZ' 'EE' 'GE' 'US' 'XK' 'MY' 'PT'
#  'SV' 'VN' 'FR' 'PK' 'SA' 'AR' 'BO' 'CN']
# cities ['Tashkent' 'Liège' 'Brussels' 'Charleroi' 'Gent' 'Namur' 'Antwerpen'
#  'Manama' 'Edinburgh' 'Norwich' 'Liverpool' 'Belfast' 'Coventry' 'Leeds'
#  'Cardiff' 'Bristol' 'London' 'Birmingham' 'Sheffield' 'Newport'
#  'Leicester' 'Manchester' 'Reading' 'Plymouth' 'Glasgow' 'Preston'
#  'Swansea' 'Luton' 'Southend-on-Sea' 'Jeonju' 'Seoul' 'Busan' 'Sejong'
#  'Ulsan' 'Yeosu' 'Gwangju' 'Seongnam-si' 'Daejeon' 'Pohang' 'Changwon'
#  'Suwon' 'Cheongju-si' 'Chuncheon' 'Daegu' 'Jeju City' 'Incheon'
#  'Suncheon' 'Mokpo' 'Andong' 'Ashgabat' 'Sydney' 'Newcastle' 'Launceston'
#  'Hobart' 'Darwin' 'Melbourne' 'Canberra' 'Adelaide' 'Brisbane' 'Perth'
#  'Wollongong' 'Hong Kong' 'Kathmandu' 'Pokhara' 'Biratnagar' 'Singapore'
#  'Stuttgart' 'Münster' 'Köln' 'Kassel' 'Karlsruhe' 'Mainz' 'Dresden'
#  'Munich' 'Berlin' 'Düsseldorf' 'Freiburg' 'Wiesbaden' 'Hannover'
#  'Augsburg' 'Darmstadt' 'Potsdam' 'Hamburg' 'Ploieşti' 'Craiova' 'Bacău'
#  'Râmnicu Vâlcea' 'Sibiu' 'Timişoara' 'Piteşti' 'Arad' 'Cluj-Napoca'
#  'Bucharest' 'Baia Mare' 'Oradea' 'Galaţi' 'Braşov' 'Iaşi' 'Constanţa'
#  'Brăila' 'Kampala' 'Hamilton' 'Calgary' 'Winnipeg' 'Halifax' 'Kitchener'
#  'Edmonton' 'Surrey' 'Mississauga' 'Québec' 'Vancouver' 'Victoria'
#  'Montréal' 'Toronto' 'Ottawa' 'Ḩawallī' 'Lima' 'Guatemala City'
#  'Thrissur' 'New Delhi' 'Hyderabad' 'Delhi' 'Chandigarh' 'Bhopal' 'Nagpur'
#  'Lucknow' 'Ghāziābād' 'Hāpur' 'Gandhinagar' 'Chennai' 'Nashik' 'Mysore'
#  'Visakhapatnam' 'Mumbai' 'Jaipur' 'Patna' 'Muzaffarnagar'
#  'Thiruvananthapuram' 'Bengaluru' 'Shillong' 'Kolkata' 'San Juan' 'Sofia'
#  'Burgas' 'Plovdiv' 'Nicosia' 'Limassol' 'Algiers' 'Tallinn' 'Tbilisi'
#  'Oklahoma City' 'Raleigh' 'Memphis' 'Jackson' 'Boston' 'Richmond'
#  'Portland' 'Boise' 'Austin' 'Honolulu' 'Fresno' 'Milwaukee' 'Columbia'
#  'Hartford' 'Washington D.C.' 'Chicago' 'Houston' 'Indianapolis' 'Atlanta'
#  'Charlotte' 'Sacramento' 'Oakland' 'Providence' 'Staten Island'
#  'Brooklyn' 'Springfield' 'The Bronx' 'San Jose' 'Los Angeles' 'Detroit'
#  'Little Rock' 'Baltimore' 'Phoenix' 'Omaha' 'El Paso' 'Dallas' 'Seattle'
#  'Manhattan' 'Miami' 'Jacksonville' 'Las Vegas' 'San Antonio'
#  'Philadelphia' 'San Diego' 'Columbus' 'Saint Paul' 'Denver'
#  'Salt Lake City' 'Albuquerque' 'San Francisco' 'Salem' 'Madison'
#  'Nashville' 'Tucson' 'Queens' 'Tallahassee' 'Fort Worth' 'Pristina'
#  'Kuantan' 'Miri' 'George Town' 'Klang' 'Malacca' 'Taiping' 'Alor Setar'
#  'Kota Bharu' 'Kuching' 'Seremban' 'Ipoh' 'Johor Bahru' 'Kuala Lumpur'
#  'Lisbon' 'Funchal' 'San Salvador' 'Ho Chi Minh City' 'Huế' 'Hanoi'
#  'Haiphong' 'Hạ Long' 'Tours' 'Marseille' 'Nîmes' 'Besançon' 'Nantes'
#  'Rennes' 'Toulouse' 'Nancy' 'Clermont-Ferrand' 'Paris' 'Lille' 'Orléans'
#  'Montpellier' 'Lyon' 'Amiens' 'Dijon' 'Rouen' 'Grenoble' 'Toulon'
#  'Limoges' 'Caen' 'Perpignan' 'Bordeaux' 'Nice' 'Saint-Étienne' 'Metz'
#  'Strasbourg' 'Karachi' 'Peshawar' 'Islamabad' 'Lahore' 'Riyadh' 'Jeddah'
#  'Abha' 'Dammam' "Ha'il" 'Buraydah' 'Mecca' 'Buenos Aires' 'Cochabamba'
#  'Beijing' 'Jieyang' 'Kunming' 'Hangzhou' 'Chongqing' 'Qingdao' 'Haikou'
#  'Ürümqi' 'Qiqihar' 'Guiyang' 'Shenzhen' 'Yunfu' 'Xuchang' 'Yinchuan'
#  'Shenyang' 'Lhasa' 'Shanghai' 'Changchun' 'Foshan' 'Nanning' 'Fushun'
#  'Hefei' 'Chengdu' 'Hohhot' 'Qinhuangdao' 'Shijiazhuang' 'Shantou'
#  'Zhengzhou' 'Nanjing' 'Xining' 'Xi’an' 'Zhuzhou' 'Wuhan' 'Tianjin'
#  'Changzhou' 'Nanchang' 'Shiyan' 'Xinxiang' 'Suzhou' 'Harbin' 'Lanzhou'
#  'Jinan' 'Changsha' 'Hegang' 'Anyang' 'Wuxi' 'Taiyuan' 'Guangzhou'
#  'Fuzhou']

# %%
histAQI = pd.read_excel('airqualitytrendsbycity1990-2019.xlsx')
histAQI.head()
# Out:
#     CBSA Core Based Statistical Area Pollutant       Trend Statistic  \
# 0  10100                Aberdeen, SD     PM2.5  Weighted Annual Mean
# 1  10100                         NaN     PM2.5       98th Percentile
# 2  10420                   Akron, OH        CO               2nd Max
# 3  10420                         NaN        O3               4th Max
# 4  10420                         NaN     PM2.5  Weighted Annual Mean
#
#    Number of Trend Sites  1990   1991   1992   1993   1994  ...    2010  \
# 0                    1.0   NaN    NaN    NaN    NaN    NaN  ...   8.700
# 1                    1.0   NaN    NaN    NaN    NaN    NaN  ...  27.000
# 2                    1.0  5.70  3.300  4.100  3.100  5.300  ...   1.400
# 3                    2.0  0.09  0.101  0.087  0.093  0.086  ...   0.074
# 4                    3.0   NaN    NaN    NaN    NaN    NaN  ...  12.400
#
#      2011    2012    2013   2014    2015   2016    2017    2018    2019
# 0   7.100   7.500   7.300   6.20   6.200   5.40   5.800   6.600   5.900
# 1  18.000  23.000  22.000  17.00  14.000  14.00  13.000  22.000  18.000
# 2   1.000   1.100   0.800   0.80   1.000   1.10   0.900   1.800   1.800
# 3   0.073   0.072   0.059   0.06   0.065   0.06   0.066   0.068   0.062
# 4  11.100  10.000   9.700   9.90  10.400   8.20   7.900   7.900   8.200
#
# [5 rows x 35 columns]

# %%
histAQI_Year_column = pd.melt(histAQI, id_vars=(['Pollutant','StateAbbr','Trend Statistic']), value_vars=([1990,
                                1991,                          1992,
                                1993,                          1994,
                                1995,                          1996,
                                1997,                          1998,
                                1999,                          2000,
                                2001,                          2002,
                                2003,                          2004,
                                2005,                          2006,
                                2007,                          2008,
                                2009,                          2010,
                                2011,                          2012,
                                2013,                          2014,
                                2015,                          2016,
                                2017,                          2018,
                                2019]), var_name='Year', value_name='Pollutant Value').dropna()
histAQI_Year_column.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-115-bd05960dd1aa> in <module>
#      14                                 2015,                          2016,
#      15                                 2017,                          2018,
# ---> 16                                 2019]), var_name='Year', value_name='Pollutant Value').dropna()
#      17 histAQI_Year_column.head()
#
# ~/.local/lib/python3.6/site-packages/pandas/core/reshape/melt.py in melt(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#      66             if not missing.empty:
#      67                 raise KeyError(
# ---> 68                     "The following 'id_vars' are not present "
#      69                     f"in the DataFrame: {list(missing)}"
#      70                 )
#
# KeyError: "The following 'id_vars' are not present in the DataFrame: ['StateAbbr']"

# %%
cities = histAQI['Core Based Statistical Area']
y = [str(i).split() for i in cities]

states = []
for i in y:
    state = i[-1]
    states.append(state)
histAQI['StateAbbr'] = states

# %%
histAQI.head()

# %%
asthma.drop(columns = ['Category','UniqueID','Measure','Short_Question_Text','Data_Value_Footnote','CategoryID','MeasureId','CityFIPS','TractFIPS'], inplace = True)
asthma.columns

# %%
#putting years in 1 column before merge
asthma_premerge = asthma[['StateAbbr','Year','Data_Value']]
asthma_premerge
# Out:
#       StateAbbr  Year  Data_Value
# 0            GA  2017         8.4
# 1            GA  2017         7.2
# 2            GA  2017         9.7
# 3            GA  2017         7.4
# 4            GA  2017        11.9
# ...         ...   ...         ...
# 29001        WY  2017         8.7
# 29002        WY  2017        10.9
# 29003        WI  2017         8.9
# 29004        WI  2017        10.0
# 29005        WI  2017        10.4
#
# [29006 rows x 3 columns]

# %%
#append adds rows
# histAQI_asthma = histAQI_Year_column.append(asthma_premerge)

#merge combines
histAQI_asthma = pd.merge(asthma_premerge,histAQI,
    how="left",                      
    left_on = ['StateAbbr'],
    right_on = ['StateAbbr'])                        
histAQI_asthma
pd.unique(histAQI_asthma['Year'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-117-e0f20753f970> in <module>
#       6     how="left",
#       7     left_on = ['StateAbbr'],
# ----> 8     right_on = ['StateAbbr'])
#       9 histAQI_asthma
#      10 pd.unique(histAQI_asthma['Year'])
#
# ~/.local/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      85         copy=copy,
#      86         indicator=indicator,
# ---> 87         validate=validate,
#      88     )
#      89     return op.get_result()
#
# ~/.local/lib/python3.6/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     650             self.right_join_keys,
#     651             self.join_names,
# --> 652         ) = self._get_merge_keys()
#     653
#     654         # validate the merge keys dtypes. We may need to coerce
#
# ~/.local/lib/python3.6/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1003                     if not is_rkey(rk):
#    1004                         if rk is not None:
# -> 1005                             right_keys.append(right._get_label_or_level_values(rk))
#    1006                         else:
#    1007                             # work-around for merge_asof(right_index=True)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1561             values = self.axes[axis].get_level_values(key)._values
#    1562         else:
# -> 1563             raise KeyError(key)
#    1564
#    1565         # Check for duplicates
#
# KeyError: 'StateAbbr'

# %%
histAQI_asthma= histAQI_asthma[histAQI_asthma.StateAbbr != 'US']

# %%
histAQI_asthma
# Out:
#        StateAbbr  Year  Data_Value   CBSA        Core Based Statistical Area  \
# 0             GA  2017         8.4  10500                         Albany, GA
# 1             GA  2017         8.4  11140                       Americus, GA
# 2             GA  2017         8.4  12060  Atlanta-Sandy Springs-Roswell, GA
# 3             GA  2017         8.4  15260                      Brunswick, GA
# 4             GA  2017         8.4  23580                    Gainesville, GA
# ...          ...   ...         ...    ...                                ...
# 301830        WI  2017        10.4  31540                        Madison, WI
# 301831        WI  2017        10.4  33340  Milwaukee-Waukesha-West Allis, WI
# 301832        WI  2017        10.4  38420                    Platteville, WI
# 301833        WI  2017        10.4  48140                         Wausau, WI
# 301834        WI  2017        10.4  48580             Whitewater-Elkhorn, WI
#
#        Pollutant       Trend Statistic  Number of Trend Sites    1990    1991  \
# 0          PM2.5  Weighted Annual Mean                    1.0     NaN     NaN
# 1             O3               4th Max                    1.0   0.082   0.082
# 2            NO2           Annual Mean                    1.0  15.000  14.000
# 3          PM2.5  Weighted Annual Mean                    1.0     NaN     NaN
# 4          PM2.5  Weighted Annual Mean                    1.0     NaN     NaN
# ...          ...                   ...                    ...     ...     ...
# 301830        O3               4th Max                    2.0   0.077   0.082
# 301831        O3               4th Max                    2.0   0.095   0.104
# 301832     PM2.5  Weighted Annual Mean                    1.0     NaN     NaN
# 301833        O3               4th Max                    1.0   0.081   0.081
# 301834        O3               4th Max                    1.0   0.077   0.095
#
#         ...    2010    2011    2012    2013    2014    2015    2016   2017  \
# 0       ...  12.300  12.100  10.600  10.000  10.300   9.000   8.700  9.400
# 1       ...   0.069   0.066   0.065   0.060   0.059   0.057   0.065  0.058
# 2       ...  14.000  13.000  12.000   9.000  11.000  10.000  11.000  9.000
# 3       ...  10.600   8.900   7.500   8.200   8.600   7.300   7.900  7.500
# 4       ...  11.400  10.700   9.300   8.500   8.900   7.900   8.500  7.600
# ...     ...     ...     ...     ...     ...     ...     ...     ...    ...
# 301830  ...   0.062   0.068   0.074   0.067   0.068   0.064   0.068  0.064
# 301831  ...   0.079   0.074   0.092   0.069   0.072   0.069   0.074  0.072
# 301832  ...  10.300  10.400   9.100   8.900   8.100   7.900   6.800  6.800
# 301833  ...   0.060   0.065   0.069   0.063   0.064   0.063   0.068  0.060
# 301834  ...   0.065   0.069   0.077   0.067   0.073   0.067   0.072  0.065
#
#          2018   2019
# 0       8.400  9.300
# 1       0.062  0.062
# 2       8.000  9.000
# 3       6.300  7.600
# 4       7.600  9.300
# ...       ...    ...
# 301830  0.066  0.059
# 301831  0.073  0.066
# 301832  8.400  8.400
# 301833  0.065  0.059
# 301834  0.070  0.070
#
# [301833 rows x 38 columns]

# %%
#copied code to fill in values from histAQI_asthma
sns.lineplot(x = "Year", y = "Pollutant Value", data = histAQI_Year_column)
plt.title('Total Pollutant Values over Time')
plt.show()
# Out:
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.lineplot(x = "Year", y = "Pollutant Value", data = histAQI_Year_column)
plt.title('Total Pollutant Values over Time')
plt.show()
# Out:
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.lineplot(x = "Year", y = "Pollutant Value", data = histAQI_Year_column, hue = "Pollutant")
plt.title('Pollutant Values over Time')
plt.show()
# Out:
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
demographics_data = pd.read_csv("https://data.cdc.gov/resource/vbim-akqf.csv")

# %%
demographics_data.groupby('race_ethnicity_combined').size()
# Out:
# race_ethnicity_combined
# American Indian/Alaska Native, Non-Hispanic              20
# Asian, Non-Hispanic                                       1
# Black, Non-Hispanic                                     130
# Missing                                                   1
# Multiple/Other, Non-Hispanic                              2
# Native Hawaiian/Other Pacific Islander, Non-Hispanic     14
# Unknown                                                  16
# White, Non-Hispanic                                     816
# dtype: int64

# %%
demographics_data.describe()
# Out:
#                   cdc_report_dt              pos_spec_dt  \
# count                      1000                     1000
# unique                       22                        1
# top     2020-11-14T00:00:00.000  2020-11-10T00:00:00.000
# freq                        194                     1000
#
#                        onset_dt             current_status     sex  \
# count                       546                       1000    1000
# unique                       28                          2       4
# top     2020-11-10T00:00:00.000  Laboratory-confirmed case  Female
# freq                        148                        975     825
#
#             age_group race_ethnicity_combined  hosp_yn   icu_yn death_yn  \
# count            1000                    1000     1000     1000     1000
# unique              1                       8        4        3        4
# top     10 - 19 Years     White, Non-Hispanic  Missing  Missing       No
# freq             1000                     816      476      612      599
#
#        medcond_yn
# count        1000
# unique          4
# top       Missing
# freq          595
