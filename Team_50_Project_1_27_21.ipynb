# %%
import json
import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy

# %%
testing_sites_df =  pd.read_csv('https://raw.githubusercontent.com/dcrago/Team50_Project/main/COVID-19%20Testing%20Locations%20Symbolized%20by%20Test%20Type.csv?token=ARUM6ZH3KD753H5N4JWLZBTACDUVM')

# %%
testing_sites_df.drop(columns = ['Owner Name','Phone','Website','Operational Hours','Vehicle Capacity','CreationDate','Drive-through','Appointment Only','Referral Required','Call first','Virtual/Telehealth Screening','Local Health Department URL','Vehicle Required','Offering same-day diagnostic (not antibody) results','Offering Take-Home Test','Status Color'], inplace = True)
testing_sites_df.drop(columns = ['Public Form Submission','Minimum Age','Wheelchair accessibility ','Accessibility Support'], inplace = True)

# %%
testing_sites_df['county']= testing_sites_df['County']
testing_sites_df
testing_sites_df.sort_values(by ='County')
# Out:
#                              Name of Facility  \
# 8858                              CHC Enfield
# 6809                           ALBERTSONS 184
# 4850       Family Medicine Health Center-Kuna
# 6802                           ALBERTSONS 169
# 3895   Rite Aid/Project Baseline Testing Site
# ...                                       ...
# 10788                   CIC Health Middlebury
# 10789                  CIC Health Brattleboro
# 10790                       CIC Health Newton
# 10791                    CIC Health Cambridge
# 10792                   CIC Health Providence
#
#                                             Full Address Municipality  \
# 8858                    5 North Main Street, Enfield, CT      Enfield
# 6809             6560 SOUTH FEDERAL WAY, Boise ID, 83716        Boise
# 4850   708 E Wythe Creek Ct Ste 103, Kuna, ID 83634-5005         Kuna
# 6802           909 EAST PARKCENTER BLVD, Boise ID, 83706        Boise
# 3895                     3250 S Eagle Road  Meridian, ID     Meridian
# ...                                                  ...          ...
# 10788            154 Creek Rd, Middlebury, VT 05753, USA   Middlebury
# 10789         17 Belmont Ave, Brattleboro, VT 05301, USA  Brattleboro
# 10790  Riverside MBTA Station Parking Lot, 367 Grove ...       Newton
# 10791  Ground Floor, 245 Main St, Cambridge, MA 02142...    Cambridge
# 10792  Ground Floor, 225 Dyer St, Providence, RI 0290...   Providence
#
#                        Owner Type  Daily Testing Capacity  \
# 8858                         FQHC                     NaN
# 6809                      Private                     NaN
# 4850                         FQHC                     NaN
# 6802                      Private                     NaN
# 3895   Public-Private Partnership                     NaN
# ...                           ...                     ...
# 10788  Public-Private Partnership                     NaN
# 10789  Public-Private Partnership                     NaN
# 10790  Public-Private Partnership                     NaN
# 10791  Public-Private Partnership                     NaN
# 10792  Public-Private Partnership                     NaN
#
#                            Services Offered State or Territory     County  \
# 8858   COVID-19 testing only (no screening)        Connecticut   Hartford
# 6809         COVID-19 screening and testing              Idaho        Ada
# 4850         COVID-19 screening and testing              Idaho        Ada
# 6802         COVID-19 screening and testing              Idaho        Ada
# 3895         COVID-19 screening and testing              Idaho        Ada
# ...                                     ...                ...        ...
# 10788  COVID-19 testing only (no screening)            Vermont        NaN
# 10789  COVID-19 testing only (no screening)            Vermont        NaN
# 10790  COVID-19 testing only (no screening)      Massachusetts        NaN
# 10791  COVID-19 testing only (no screening)      Massachusetts        NaN
# 10792  COVID-19 testing only (no screening)       Rhode Island        NaN
#
#       Testing Start Date Testing End Date Kind of test Processing location  \
# 8858           11/3/2020        11/3/2020    Molecular       Not Specified
# 6809           8/16/2020              NaN    Molecular         Offsite Lab
# 4850                 NaN              NaN    Molecular         Offsite Lab
# 6802           8/16/2020              NaN    Molecular         Offsite Lab
# 3895                 NaN              NaN    Molecular         Offsite Lab
# ...                  ...              ...          ...                 ...
# 10788                NaN              NaN    Molecular         Offsite Lab
# 10789                NaN              NaN    Molecular         Offsite Lab
# 10790                NaN              NaN    Molecular         Offsite Lab
# 10791                NaN              NaN    Molecular         Offsite Lab
# 10792                NaN              NaN    Molecular         Offsite Lab
#
#                           Facility Type             x            y     county
# 8858   Mobile/Pop-up (short-term event) -8.082311e+06  5160794.778   Hartford
# 6809                    Retail/Pharmacy -1.293014e+07  5394986.099        Ada
# 4850               Clinic/Health Center -1.295815e+07  5386506.524        Ada
# 6802                    Retail/Pharmacy -1.293219e+07  5401123.670        Ada
# 3895                    Retail/Pharmacy -1.295245e+07  5399916.908        Ada
# ...                                 ...           ...          ...        ...
# 10788       Indoor Non-medical Facility -8.144216e+06  5465912.348        NaN
# 10789       Indoor Non-medical Facility -8.077923e+06  5288098.494        NaN
# 10790       Indoor Non-medical Facility -7.931803e+06  5211651.232        NaN
# 10791       Indoor Non-medical Facility -7.913119e+06  5215443.009        NaN
# 10792       Indoor Non-medical Facility -7.949150e+06  5134076.563        NaN
#
# [10804 rows x 16 columns]

# %%
testing_sites_df['county_states']= testing_sites_df['county'] + ' , ' + testing_sites_df['State or Territory']
testing_sites_bycounty = testing_sites_df.groupby('county').count()

# %%
_ = testing_sites_df['county_states'].unique
_
# Out:
# <bound method Series.unique of 0             Ohio , West Virginia
# 1            Essex , Massachusetts
# 2         Allegheny , Pennsylvania
# 3                Orange , New York
# 4         Allegheny , Pennsylvania
#                    ...
# 10799             Clark , Missouri
# 10800     Marshall , West Virginia
# 10801              Cook , Illinois
# 10802              Cuyahoga , Ohio
# 10803    Grand Traverse , Michigan
# Name: county_states, Length: 10804, dtype: object>

# %%
Covid_data = pd.read_csv("https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv")

# %%
asthma = pd.read_csv('https://raw.githubusercontent.com/dcrago/Team50_Project/main/500_Cities__Current_asthma_among_adults_aged___18_years.csv?token=ARUM6ZAX353XYL2UAZK5MJDACDZYS')

# %%
Covid_data['mortality'] = Covid_data['deaths']/Covid_data['cases']
Covid_data.tail()
# Out:
#               date      county    state     fips  cases  deaths  mortality
# 956211  2021-01-22  Sweetwater  Wyoming  56037.0   3384    30.0   0.008865
# 956212  2021-01-22       Teton  Wyoming  56039.0   2870     5.0   0.001742
# 956213  2021-01-22       Uinta  Wyoming  56041.0   1887    12.0   0.006359
# 956214  2021-01-22    Washakie  Wyoming  56043.0    852    25.0   0.029343
# 956215  2021-01-22      Weston  Wyoming  56045.0    609     4.0   0.006568

# %%
testing_sites_covid = Covid_data.merge(testing_sites_bycounty,
    how='inner',
    on = 'county'
)

testing_sites_covid = testing_sites_covid[testing_sites_covid['date']=='2021-01-25'
]
testing_sites_covid = testing_sites_covid.iloc[0:,0:7].rename(columns = {'Name of Facility': 'Number of Testing Sites'})
testing_sites_covid['Mortality Rate'] =
# Out:
#               date       county       state     fips   cases  deaths  \
# 370     2021-01-25    Snohomish  Washington  53061.0   27995   470.0
# 1265    2021-01-25         Cook     Georgia  13075.0    1539    33.0
# 1266    2021-01-25         Cook    Illinois  17031.0  446035  9268.0
# 1267    2021-01-25         Cook   Minnesota  27031.0     116     0.0
# 3814    2021-01-25       Orange  California   6059.0  237708  2704.0
# ...            ...          ...         ...      ...     ...     ...
# 528969  2021-01-25  Sweet Grass     Montana  30097.0     328     6.0
# 529158  2021-01-25     Chouteau     Montana  30015.0     429     5.0
# 529339  2021-01-25        Modoc  California   6049.0     285     3.0
# 529494  2021-01-25      Rawlins      Kansas  20153.0     341     7.0
# 529608  2021-01-25        Hayes    Nebraska  31085.0      58     0.0
#
#         Number of Testing Sites
# 370                          57
# 1265                        368
# 1266                        368
# 1267                        368
# 3814                         31
# ...                         ...
# 528969                        1
# 529158                        2
# 529339                        3
# 529494                        1
# 529608                        2
#
# [1765 rows x 7 columns]

# %%
mort_county.corr()[['asthma_value_times_count', 'confirmed_deaths']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-acabf59083a0> in <module>
# ----> 1 mort_county.corr()[['asthma_value_times_count', 'confirmed_deaths']]
#
# NameError: name 'mort_county' is not defined

# %%
asthma['state'] = asthma['StateDesc']
asthma['asthma_value_times_count'] = (asthma['Data_Value'] * asthma['PopulationCount'])/100
asthma['asthma_value_times_count']
# Out:
# 0         528.612
# 1        5524.416
# 2         478.986
# 3         359.048
# 4         244.664
#            ...
# 29001     403.506
# 29002      45.235
# 29003     135.013
# 29004     137.800
# 29005     363.792
# Name: asthma_value_times_count, Length: 29006, dtype: float64

# %%
asthma.head()
# Out:
#    Year StateAbbr StateDesc       CityName GeographicLevel DataSource  \
# 0  2017        GA   Georgia       Columbus    Census Tract      BRFSS
# 1  2017        GA   Georgia    Johns Creek            City      BRFSS
# 2  2017        GA   Georgia  Sandy Springs    Census Tract      BRFSS
# 3  2017        GA   Georgia        Roswell    Census Tract      BRFSS
# 4  2017        GA   Georgia       Savannah    Census Tract      BRFSS
#
#           Category             UniqueID  \
# 0  Health Outcomes  1319000-13215010302
# 1  Health Outcomes              1342425
# 2  Health Outcomes  1368516-13121010119
# 3  Health Outcomes  1367284-13121011423
# 4  Health Outcomes  1369000-13051002300
#
#                                        Measure Data_Value_Unit  ...  \
# 0  Current asthma among adults aged >=18 Years               %  ...
# 1  Current asthma among adults aged >=18 Years               %  ...
# 2  Current asthma among adults aged >=18 Years               %  ...
# 3  Current asthma among adults aged >=18 Years               %  ...
# 4  Current asthma among adults aged >=18 Years               %  ...
#
#   Data_Value_Footnote PopulationCount                      GeoLocation  \
# 0                 NaN            6293   (32.5420961469, -84.975715442)
# 1                 NaN           76728  (34.0332991998, -84.2027195506)
# 2                 NaN            4938  (33.9913040108, -84.3452326148)
# 3                 NaN            4852  (34.0177367078, -84.3840157981)
# 4                 NaN            2056  (32.0577200508, -81.1112836355)
#
#    CategoryID  MeasureId   CityFIPS     TractFIPS  Short_Question_Text  \
# 0     HLTHOUT    CASTHMA  1319000.0  1.321501e+10       Current Asthma
# 1     HLTHOUT    CASTHMA  1342425.0           NaN       Current Asthma
# 2     HLTHOUT    CASTHMA  1368516.0  1.312101e+10       Current Asthma
# 3     HLTHOUT    CASTHMA  1367284.0  1.312101e+10       Current Asthma
# 4     HLTHOUT    CASTHMA  1369000.0  1.305100e+10       Current Asthma
#
#      state asthma_value_times_count
# 0  Georgia                  528.612
# 1  Georgia                 5524.416
# 2  Georgia                  478.986
# 3  Georgia                  359.048
# 4  Georgia                  244.664
#
# [5 rows x 26 columns]

# %%
asthma1 = asthma.groupby(['state']).sum()
asthma1 = asthma1.iloc[0:, [7]].drop('United States', axis = 0).rename(columns = {'asthma_value_times_count': 'Population with Asthma'})
asthma1.to_csv('asthma.csv')

# %%
from IPython.display import HTML

# %%
census_insurance = pd.read_csv('https://www2.census.gov/programs-surveys/demo/datasets/income-poverty/time-series/data-extracts/2018/cps-asec-bridge-file/hhpub18.csv')
census_insurance.columns
#HCOV NOW_HCOV 
# HTML(filename='www.census.gov/data/tables/time-series/demo/health-insurance/historical-series/hib.html')
# Out:
# Index(['H_IDNUM', 'GEREG', 'GESTFIPS', 'GEDIV', 'HRHTYPE', 'HEFAMINC',
#        'H_MONTH', 'H_YEAR', 'H_TENURE', 'H_HHNUM',
#        ...
#        'THCHCARE_VAL', 'THPROP_VAL', 'GTCBSA', 'GTCO', 'GTCBSAST', 'GTCBSASZ',
#        'GTCSA', 'GTMETSTA', 'GTINDVPC', 'MMYY'],
#       dtype='object', length=134)

# %%
# Covid_data & asthma
var_of_interest= ['confirmed_deaths','confirmed_cases', ]

# %%
covid_asthma = pd.merge(asthma1,Covid_data,
    how="left",                      
    left_on = ['state'],
    right_on = ['state']).set_index('state')

covid_asthma.to_csv('covid_asthma.csv')

# %%
covid_asthma
# Out:
#          Population with Asthma        date      county     fips   cases  \
# state
# Alabama              328047.371  2020-03-13      Elmore   1051.0     1.0
# Alabama              328047.371  2020-03-13   Jefferson   1073.0     2.0
# Alabama              328047.371  2020-03-13   Limestone   1083.0     1.0
# Alabama              328047.371  2020-03-13  Montgomery   1101.0     1.0
# Alabama              328047.371  2020-03-13  Tuscaloosa   1125.0     1.0
# ...                         ...         ...         ...      ...     ...
# Wyoming               17123.431  2021-01-25  Sweetwater  56037.0  3418.0
# Wyoming               17123.431  2021-01-25       Teton  56039.0  2981.0
# Wyoming               17123.431  2021-01-25       Uinta  56041.0  1913.0
# Wyoming               17123.431  2021-01-25    Washakie  56043.0   860.0
# Wyoming               17123.431  2021-01-25      Weston  56045.0   610.0
#
#          deaths
# state
# Alabama     0.0
# Alabama     0.0
# Alabama     0.0
# Alabama     0.0
# Alabama     0.0
# ...         ...
# Wyoming    30.0
# Wyoming     5.0
# Wyoming    12.0
# Wyoming    25.0
# Wyoming     4.0
#
# [897887 rows x 6 columns]

# %%
covid_asthma.corr()[['asthma_value_times_count', 'confirmed_deaths']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-eb4d5c991e2b> in <module>
# ----> 1 covid_asthma.corr()[['asthma_value_times_count', 'confirmed_deaths']]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1302             if raise_missing:
#    1303                 not_found = list(set(key) - set(ax))
# -> 1304                 raise KeyError(f"{not_found} not in index")
#    1305
#    1306             # we skip the warning on Categorical
#
# KeyError: "['confirmed_deaths'] not in index"

# %%
#not updated through 12/2020
with open('waqi-covid19-airqualitydata-2020.csv') as AQI:
    AQI_older = pd.read_csv(AQI)
AQI_older.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-50-f2a58b7995da> in <module>
#       1 #not updated through 12/2020
# ----> 2 with open('waqi-covid19-airqualitydata-2020.csv') as AQI:
#       3     AQI_older = pd.read_csv(AQI)
#       4 AQI_older.head()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'waqi-covid19-airqualitydata-2020.csv'

# %%
with open('./waqi-covid19-airqualitydata-2020.csv') as AQI:
    AQI_old = pd.read_csv(AQI)
AQI_old.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-53-7278840be58a> in <module>
# ----> 1 with open('./waqi-covid19-airqualitydata-2020.csv') as AQI:
#       2     AQI_old = pd.read_csv(AQI)
#       3 AQI_old.head()
#
# FileNotFoundError: [Errno 2] No such file or directory: './waqi-covid19-airqualitydata-2020.csv'

# %%
#this takes us to a document where we need to delete the first five rows bc it's just information 
#updated currently woohoo!
AQI = pd.read_excel('AQI_US.xlsx')
AQI.head()
AQI = AQI.sort_values('Date', ascending = False)

AQI
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-54-9305e09541e7> in <module>
#       1 #this takes us to a document where we need to delete the first five rows bc it's just information
#       2 #updated currently woohoo!
# ----> 3 AQI = pd.read_excel('AQI_US.xlsx')
#       4 AQI.head()
#       5 AQI = AQI.sort_values('Date', ascending = False)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path_or_buffer, engine)
#     865         self._io = stringify_path(path_or_buffer)
#     866
# --> 867         self._reader = self._engines[engine](self._io)
#     868
#     869     def __fspath__(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_xlrd.py in __init__(self, filepath_or_buffer)
#      20         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      21         import_optional_dependency("xlrd", extra=err_msg)
# ---> 22         super().__init__(filepath_or_buffer)
#      23
#      24     @property
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, filepath_or_buffer)
#     351             self.book = self.load_workbook(filepath_or_buffer)
#     352         elif isinstance(filepath_or_buffer, str):
# --> 353             self.book = self.load_workbook(filepath_or_buffer)
#     354         elif isinstance(filepath_or_buffer, bytes):
#     355             self.book = self.load_workbook(BytesIO(filepath_or_buffer))
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_xlrd.py in load_workbook(self, filepath_or_buffer)
#      35             return open_workbook(file_contents=data)
#      36         else:
# ---> 37             return open_workbook(filepath_or_buffer)
#      38
#      39     @property
#
# ~\anaconda3\lib\site-packages\xlrd\__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     109     else:
#     110         filename = os.path.expanduser(filename)
# --> 111         with open(filename, "rb") as f:
#     112             peek = f.read(peeksz)
#     113     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: 'AQI_US.xlsx'

# %%
pd.unique(AQI_US['Specie'])

# %%
#lists of cities

print('cities', pd.unique(AQI['City']))

# %%
histAQI = pd.read_excel('./data/airqualitytrendsbycity1990-2019.zip')
histAQI.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a3243371d856> in <module>
# ----> 1 histAQI = pd.read_excel('./data/airqualitytrendsbycity1990-2019.zip')
#       2 histAQI.head()
#
# NameError: name 'pd' is not defined

# %%
histAQI_Year_column = pd.melt(histAQI, id_vars=(['Pollutant','StateAbbr','Trend Statistic']), value_vars=([1990,
                                1991,                          1992,
                                1993,                          1994,
                                1995,                          1996,
                                1997,                          1998,
                                1999,                          2000,
                                2001,                          2002,
                                2003,                          2004,
                                2005,                          2006,
                                2007,                          2008,
                                2009,                          2010,
                                2011,                          2012,
                                2013,                          2014,
                                2015,                          2016,
                                2017,                          2018,
                                2019]), var_name='Year', value_name='Pollutant Value').dropna()
histAQI_Year_column.head()

# %%
cities = histAQI['Core Based Statistical Area']
y = [str(i).split() for i in cities]

states = []
for i in y:
    state = i[-1]
    states.append(state)
histAQI['StateAbbr'] = states

# %%
histAQI.head()

# %%
asthma.drop(columns = ['Category','UniqueID','Measure','Short_Question_Text','Data_Value_Footnote','CategoryID','MeasureId','CityFIPS','TractFIPS'], inplace = True)
asthma.columns

# %%
#putting years in 1 column before merge
asthma_premerge = asthma[['StateAbbr','Year','Data_Value']]
asthma_premerge

# %%
#append adds rows
# histAQI_asthma = histAQI_Year_column.append(asthma_premerge)

#merge combines
AQI_asthma = pd.merge(asthma_premerge,AQI,
    how="left",                      
    left_on = ['StateAbbr'],
    right_on = ['StateAbbr'])                        
AQI_asthma
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-a07a15760c5a> in <module>
#       3
#       4 #merge combines
# ----> 5 AQI_asthma = pd.merge(asthma_premerge,AQI,
#       6     how="left",
#       7     left_on = ['StateAbbr'],
#
# NameError: name 'asthma_premerge' is not defined

# %%
histAQI_asthma= histAQI_asthma[histAQI_asthma.StateAbbr != 'US']

# %%
histAQI_asthma

# %%
#copied code to fill in values from histAQI_asthma
sns.lineplot(x = "Year", y = "Pollutant Value", data = histAQI_Year_column)
plt.title('Total Pollutant Values over Time')
plt.show()

# %%
sns.lineplot(x = "Year", y = "Pollutant Value", data = histAQI_Year_column)
plt.title('Total Pollutant Values over Time')
plt.show()

# %%
sns.lineplot(x = "Year", y = "Pollutant Value", data = histAQI_Year_column, hue = "Pollutant")
plt.title('Pollutant Values over Time')
plt.show()

# %%
demographics_data = pd.read_csv("https://data.cdc.gov/resource/vbim-akqf.csv")

# %%
demographics_data.groupby('race_ethnicity_combined').size()

# %%
demographics_data.describe()
