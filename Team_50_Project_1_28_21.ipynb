# %%
import json
import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy

# %% [markdown]
# # Testing Sites

# %%
testing_sites_df =  pd.read_csv('https://raw.githubusercontent.com/dcrago/Team50_Project/main/COVID-19%20Testing%20Locations%20Symbolized%20by%20Test%20Type.csv?token=ARUSVWL2E75VLQXSQ5HVWPTAA6EAG')

# %%
testing_sites_df.drop(columns = ['Owner Name','Phone','Website','Operational Hours','Vehicle Capacity','CreationDate','Drive-through','Appointment Only','Referral Required','Call first','Virtual/Telehealth Screening','Local Health Department URL','Vehicle Required','Offering same-day diagnostic (not antibody) results','Offering Take-Home Test','Status Color'], inplace = True)
testing_sites_df.drop(columns = ['Public Form Submission','Minimum Age','Wheelchair accessibility ','Accessibility Support'], inplace = True)

# %%
testing_sites_df['county']= testing_sites_df['County']
testing_sites_df
testing_sites_df.sort_values(by ='County')

# %%
testing_sites_df['county_states']= testing_sites_df['county'] + ' , ' + testing_sites_df['State or Territory']
testing_sites_df

# %%
_ = testing_sites_df['county_states'].unique
_

# %% [markdown]
# # Covid

# %%
Covid_data = pd.read_csv("https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv")

# %%
Covid_data['mortality'] = Covid_data['deaths']/Covid_data['cases']
Covid_data.tail()
# Out:
#               date      county    state     fips  cases  deaths  mortality
# 972436  2021-01-27  Sweetwater  Wyoming  56037.0   3428    32.0   0.009335
# 972437  2021-01-27       Teton  Wyoming  56039.0   3020     6.0   0.001987
# 972438  2021-01-27       Uinta  Wyoming  56041.0   1948    12.0   0.006160
# 972439  2021-01-27    Washakie  Wyoming  56043.0    863    25.0   0.028969
# 972440  2021-01-27      Weston  Wyoming  56045.0    610     4.0   0.006557

# %% [markdown]
# # Merge covid testing sites

# %%
testing_sites_covid = Covid_data.merge(testing_sites_df,
    how='inner',
    on = 'county'
)

testing_sites_covid
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6a5d84c02851> in <module>
# ----> 1 testing_sites_covid = Covid_data.merge(testing_sites_df,
#       2     how='inner',
#       3     on = 'county'
#       4 )
#       5
#
# NameError: name 'testing_sites_df' is not defined

# %%
mort_county.corr()[['asthma_value_times_count', 'confirmed_deaths']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-acabf59083a0> in <module>
# ----> 1 mort_county.corr()[['asthma_value_times_count', 'confirmed_deaths']]
#
# NameError: name 'mort_county' is not defined

# %% [markdown]
# # Asthma

# %%
asthma = pd.read_csv('500_Cities__Current_asthma_among_adults_aged___18_years.csv')

# %%
asthma['state'] = asthma['StateDesc']
asthma['asthma_value_times_count'] = (asthma['Data_Value'] * asthma['PopulationCount'])/100
asthma['asthma_value_times_count']
# Out:
# 0         528.612
# 1        5524.416
# 2         478.986
# 3         359.048
# 4         244.664
#            ...
# 29001     403.506
# 29002      45.235
# 29003     135.013
# 29004     137.800
# 29005     363.792
# Name: asthma_value_times_count, Length: 29006, dtype: float64

# %% [markdown]
# # asthma.drop(columns = ['Category','UniqueID','Measure','Short_Question_Text','Data_Value_Footnote','CategoryID','MeasureId','CityFIPS','TractFIPS'], inplace = True)
# asthma.columns

# %%
from IPython.display import HTML

# %%
'''
changed aggfunc to mean because were dealing with percentage value, 
sum misrepresented the data
'''

asthma1 = asthma.groupby(['state']).mean()
asthma_state_count = asthma1['asthma_value_times_count']
asthma1
# Out:
#                  Year  Data_Value  Low_Confidence_Limit  \
# state
# Alabama        2017.0   11.425490             10.760224
# Alaska         2017.0    9.040351              8.621053
# Arizona        2017.0   10.344531              9.794141
# Arkansas       2017.0    9.733594              9.216406
# California     2017.0    8.897829              8.427422
# Colorado       2017.0    9.454213              8.948455
# Connecticut    2017.0   10.980085             10.433051
# Delaware       2017.0   12.065385             11.392308
# District of C  2017.0   10.266111              9.639444
# Florida        2017.0    8.749375              8.273769
# Georgia        2017.0    9.877253              9.292918
# Hawaii         2017.0    8.848729              8.496186
# Idaho          2017.0    9.471233              8.954795
# Illinois       2017.0    9.436790              8.872067
# Indiana        2017.0   11.068843             10.452612
# Iowa           2017.0    9.690594              9.169802
# Kansas         2017.0    9.502903              9.017097
# Kentucky       2017.0   10.698120             10.112406
# Louisiana      2017.0    9.966142              9.334908
# Maine          2017.0   10.359091              9.813636
# Maryland       2017.0   11.478109             10.761692
# Massachusetts  2017.0   11.256863             10.662157
# Michigan       2017.0   12.239153             11.531481
# Minnesota      2017.0    8.173457              7.733642
# Mississippi    2017.0   11.103797             10.379747
# Missouri       2017.0    9.904740              9.343567
# Montana        2017.0    9.414894              8.887234
# Nebraska       2017.0    8.663761              8.178899
# Nevada         2017.0   10.050678              9.542818
# New Hampshire  2017.0   11.100000             10.482353
# New Jersey     2017.0    9.969255              9.408075
# New Mexico     2017.0    9.806542              9.310748
# New York       2017.0   10.044032              9.471895
# North Carolin  2017.0    9.820833              9.283460
# North Dakota   2017.0    8.533333              8.003704
# Ohio           2017.0   11.116329             10.480691
# Oklahoma       2017.0   10.470190              9.941015
# Oregon         2017.0   10.383523              9.838068
# Pennsylvania   2017.0   11.165581             10.529302
# Rhode Island   2017.0   12.115094             11.507547
# South Carolin  2017.0    9.938418              9.330508
# South Dakota   2017.0    8.538333              8.070000
# Tennessee      2017.0   10.802294             10.161185
# Texas          2017.0    8.508445              8.013846
# United States  2017.0    8.950000              8.800000
# Utah           2017.0    9.296813              8.775299
# Vermont        2017.0   11.153846             10.338462
# Virginia       2017.0   10.224376              9.683877
# Washington     2017.0   10.088136              9.603766
# West Virginia  2017.0   11.266667             10.700000
# Wisconsin      2017.0   10.694203             10.070773
# Wyoming        2017.0    9.644444              9.155556
#
#                High_Confidence_Limit  PopulationCount  \
# state
# Alabama                    12.210084     7.620821e+03
# Alaska                      9.522807     1.535926e+04
# Arizona                    10.979785     1.099551e+04
# Arkansas                   10.329687     1.114484e+04
# California                  9.427933     1.196123e+04
# Colorado                   10.052247     1.023229e+04
# Connecticut                11.602542     1.107831e+04
# Delaware                   12.830769     8.175115e+03
# District of C              11.047222     9.973309e+03
# Florida                     9.306025     1.109481e+04
# Georgia                    10.566738     9.821329e+03
# Hawaii                      9.244492     1.186565e+04
# Idaho                      10.076712     1.468865e+04
# Illinois                   10.102650     9.964732e+03
# Indiana                    11.792164     1.002270e+04
# Iowa                       10.308416     9.218900e+03
# Kansas                     10.074194     9.804207e+03
# Kentucky                   11.390977     9.960669e+03
# Louisiana                  10.703937     7.958491e+03
# Maine                      11.059091     9.026455e+03
# Maryland                   12.321891     9.222193e+03
# Massachusetts              11.959412     1.088302e+04
# Michigan                   13.058730     8.602836e+03
# Minnesota                   8.695062     1.003003e+04
# Mississippi                11.955696     9.049013e+03
# Missouri                   10.571106     9.066694e+03
# Montana                    10.046809     1.068488e+04
# Nebraska                    9.250000     8.977628e+03
# Nevada                     10.630081     1.081835e+04
# New Hampshire              11.809804     1.153288e+04
# New Jersey                 10.592857     1.098013e+04
# New Mexico                 10.381776     1.065251e+04
# New York                   10.700000     1.112021e+04
# North Carolin              10.460606     1.001840e+04
# North Dakota                9.211111     1.172767e+04
# Ohio                       11.850894     8.100438e+03
# Oklahoma                   11.086047     8.429455e+03
# Oregon                     11.031818     1.072240e+04
# Pennsylvania               11.919535     1.044383e+04
# Rhode Island               12.813208     1.155838e+04
# South Carolin              10.667232     7.839505e+03
# South Dakota                9.106667     1.056400e+04
# Tennessee                  11.550669     1.003466e+04
# Texas                       9.070998     1.152274e+04
# United States               9.150000     3.087455e+08
# Utah                        9.919124     1.046002e+04
# Vermont                    12.161538     9.788538e+03
# Virginia                   10.857006     1.100226e+04
# Washington                 10.662335     1.129255e+04
# West Virginia              11.933333     5.930769e+03
# Wisconsin                  11.429710     8.869231e+03
# Wyoming                    10.188889     9.911000e+03
#
#                asthma_value_times_count
# state
# Alabama                    9.189002e+02
# Alaska                     1.379812e+03
# Arizona                    1.181525e+03
# Arkansas                   1.111260e+03
# California                 1.081963e+03
# Colorado                   1.001540e+03
# Connecticut                1.199748e+03
# Delaware                   9.842651e+02
# District of C              1.003154e+03
# Florida                    9.895027e+02
# Georgia                    9.588037e+02
# Hawaii                     1.075026e+03
# Idaho                      1.414893e+03
# Illinois                   9.285785e+02
# Indiana                    1.105926e+03
# Iowa                       9.280620e+02
# Kansas                     9.390508e+02
# Kentucky                   1.072906e+03
# Louisiana                  7.952681e+02
# Maine                      9.309913e+02
# Maryland                   1.047978e+03
# Massachusetts              1.226017e+03
# Michigan                   1.052045e+03
# Minnesota                  8.135067e+02
# Mississippi                1.003402e+03
# Missouri                   9.271810e+02
# Montana                    1.029023e+03
# Nebraska                   7.956367e+02
# Nevada                     1.119246e+03
# New Hampshire              1.268147e+03
# New Jersey                 1.066895e+03
# New Mexico                 1.101874e+03
# New York                   1.110515e+03
# North Carolin              1.034978e+03
# North Dakota               9.874790e+02
# Ohio                       9.012827e+02
# Oklahoma                   8.910663e+02
# Oregon                     1.182436e+03
# Pennsylvania               1.190699e+03
# Rhode Island               1.406954e+03
# South Carolin              7.863047e+02
# South Dakota               9.416517e+02
# Tennessee                  1.127711e+03
# Texas                      1.021355e+03
# United States              2.763273e+07
# Utah                       1.038111e+03
# Vermont                    1.092510e+03
# Virginia                   1.110135e+03
# Washington                 1.180832e+03
# West Virginia              7.214060e+02
# Wisconsin                  9.569464e+02
# Wyoming                    9.513017e+02

# %%
#putting years in 1 column before merge
#didn't use this df because we have another thats grouped by state
asthma_premerge = asthma[['StateAbbr','Year','Data_Value']]

# %% [markdown]
# # Census -people with insurance

# %%
census_insurance = pd.read_csv('https://www2.census.gov/programs-surveys/demo/datasets/income-poverty/time-series/data-extracts/2018/cps-asec-bridge-file/hhpub18.csv')
census_insurance.columns
#HCOV NOW_HCOV 
# HTML(filename='www.census.gov/data/tables/time-series/demo/health-insurance/historical-series/hib.html')
# Out:
# Index(['H_IDNUM', 'GEREG', 'GESTFIPS', 'GEDIV', 'HRHTYPE', 'HEFAMINC',
#        'H_MONTH', 'H_YEAR', 'H_TENURE', 'H_HHNUM',
#        ...
#        'THCHCARE_VAL', 'THPROP_VAL', 'GTCBSA', 'GTCO', 'GTCBSAST', 'GTCBSASZ',
#        'GTCSA', 'GTMETSTA', 'GTINDVPC', 'MMYY'],
#       dtype='object', length=134)

# %% [markdown]
# # Merging covid and asthma data

# %%
# Covid_data & asthma
var_of_interest= ['confirmed_deaths','confirmed_cases', ]

# %%
covid_asthma = pd.merge(asthma1,Covid_data,
    how="left",                      
    left_on = ['state'],
    right_on = ['state']) 
# covid_asthma.drop('United States', axis = 0)
covasdrop= ['fips','Low_Confidence_Limit','High_Confidence_Limit','Year','asthma_value_times_count','PopulationCount']
covid_asthma = covid_asthma.drop(columns = covasdrop)
covid_asthma = covid_asthma.rename(columns={'Data_Value':'perc pop with asthma','mortality':'covid mortality'})

# %%
covid_asthma
# Out:
#           state  perc pop with asthma        date      county   cases  deaths  \
# 0       Alabama             11.425490  2020-03-13      Elmore     1.0     0.0
# 1       Alabama             11.425490  2020-03-13   Jefferson     2.0     0.0
# 2       Alabama             11.425490  2020-03-13   Limestone     1.0     0.0
# 3       Alabama             11.425490  2020-03-13  Montgomery     1.0     0.0
# 4       Alabama             11.425490  2020-03-13  Tuscaloosa     1.0     0.0
# ...         ...                   ...         ...         ...     ...     ...
# 903908  Wyoming              9.644444  2021-01-27  Sweetwater  3428.0    32.0
# 903909  Wyoming              9.644444  2021-01-27       Teton  3020.0     6.0
# 903910  Wyoming              9.644444  2021-01-27       Uinta  1948.0    12.0
# 903911  Wyoming              9.644444  2021-01-27    Washakie   863.0    25.0
# 903912  Wyoming              9.644444  2021-01-27      Weston   610.0     4.0
#
#         covid mortality
# 0              0.000000
# 1              0.000000
# 2              0.000000
# 3              0.000000
# 4              0.000000
# ...                 ...
# 903908         0.009335
# 903909         0.001987
# 903910         0.006160
# 903911         0.028969
# 903912         0.006557
#
# [903913 rows x 7 columns]

# %%
covid_asthma.corr()[['perc pop with asthma', 'deaths']]
# Out:
#                       perc pop with asthma    deaths
# perc pop with asthma              1.000000  0.013371
# cases                            -0.019744  0.735856
# deaths                            0.013371  1.000000
# covid mortality                   0.027450  0.013347

# %% [markdown]
# # AQI

# %%
# #not updated through 12/2020
# with open('waqi-covid19-airqualitydata-2020.csv') as AQI:
#     AQI_older = pd.read_csv(AQI)
# AQI_older.head()

# %%
# with open('waqi-covid19-airqualitydata-2020.csv') as AQI:
#     AQI_old = pd.read_csv(AQI)
# AQI_old.head()

# %%
#this takes us to a document where we need to delete the first five rows bc it's just information 
#updated currently woohoo!
AQI = pd.read_excel('AQI_US.xlsx')
AQI.head()
AQI = AQI.sort_values('Date', ascending = False)
AQIbig6list=['so2','pm10','pm25','co','no2','o3']
AQI_big6df= AQI[AQI['Specie'].isin(AQIbig6list)]





# AQI_average_values = pd.pivot_table(AQI_big6df, index = ['City'], values = 'median', columns = 'Specie',aggfunc = 'mean')
# AQI_average_values_big6 = AQI_average_values[AQI_average_values['so2','pm10','pm25','co','no2','03']]
# AQI_average_values_big6
# aqigroup=['City','Specie']
# AQI_average_values = AQI_big6df.groupby(by = aqigroup).mean()
# AQI.to_csv('AQI.csv')

# %%
AQI_big6df
# Out:
#              Date Country        City Specie  count   min   max  median  \
# 373    2021-01-21      US   Manhattan   pm25     43   1.0  59.0    21.0
# 377    2021-01-21      US       Miami   pm10     54   1.0  32.0     6.0
# 378    2021-01-21      US       Miami     o3     44   0.5  26.4     5.3
# 381    2021-01-21      US       Miami     co     48   1.9   3.8     2.5
# 367    2021-01-21      US   Manhattan    no2     16  13.0  35.2    18.6
# ...           ...     ...         ...    ...    ...   ...   ...     ...
# 212102 2019-12-30      US     Atlanta     o3     22  18.4  28.9    24.1
# 212103 2019-12-30      US     Atlanta    no2     24   1.0   9.4     3.8
# 212106 2019-12-30      US     Atlanta   pm25     44   1.0  30.0    15.0
# 212108 2019-12-30      US     Atlanta     co     23   1.4   1.9     1.7
# 212245 2019-12-30      US  Fort Worth     o3     23   4.0  31.2    18.4
#
#         variance
# 373      1314.67
# 377       462.54
# 378       824.59
# 381         2.59
# 367       629.29
# ...          ...
# 212102    112.43
# 212103     48.27
# 212106    431.44
# 212108      0.15
# 212245    526.82
#
# [93237 rows x 9 columns]

# %% [markdown]
# # Merging AQI with  city

# %% [markdown]
# Problem to overcome in the merge is that the AQI data geolocates through country and city while the covid_asthma dataset geolocates through state and county. How can we make a new column with only county or city or state for the dataset that lacks it?

# %% [markdown]
# We want to create a function that will sort the cities into the state

# %%
us_cities = pd.read_csv('uscities.csv')
us_cities['City'] = us_cities['city']
us_cities.head()
# Out:
#           city   city_ascii state_id  state_name  county_fips  county_name  \
# 0     New York     New York       NY    New York        36061     New York
# 1  Los Angeles  Los Angeles       CA  California         6037  Los Angeles
# 2      Chicago      Chicago       IL    Illinois        17031         Cook
# 3        Miami        Miami       FL     Florida        12086   Miami-Dade
# 4       Dallas       Dallas       TX       Texas        48113       Dallas
#
#        lat       lng  population  density   source  military  incorporated  \
# 0  40.6943  -73.9249    18713220  10715.0  polygon     False          True
# 1  34.1139 -118.4068    12750807   3276.0  polygon     False          True
# 2  41.8373  -87.6862     8604203   4574.0  polygon     False          True
# 3  25.7839  -80.2102     6445545   5019.0  polygon     False          True
# 4  32.7936  -96.7662     5743938   1526.0  polygon     False          True
#
#               timezone  ranking  \
# 0     America/New_York        1
# 1  America/Los_Angeles        1
# 2      America/Chicago        1
# 3     America/New_York        1
# 4      America/Chicago        1
#
#                                                 zips          id         City
# 0  11229 11226 11225 11224 11222 11221 11220 1138...  1840034016     New York
# 1  90291 90293 90292 91316 91311 90037 90031 9000...  1840020491  Los Angeles
# 2  60018 60649 60641 60640 60643 60642 60645 6064...  1840000494      Chicago
# 3  33129 33125 33126 33127 33128 33149 33144 3314...  1840015149        Miami
# 4  75287 75098 75233 75254 75251 75252 75253 7503...  1840019440       Dallas

# %%
aqi_city = pd.merge(AQI_big6df,us_cities,
    how="left",                      
    left_on = ['City'],
    right_on = ['City']) 
aqi_city.head()
# Out:
#         Date Country       City Specie  count  min   max  median  variance  \
# 0 2021-01-21      US  Manhattan   pm25     43  1.0  59.0    21.0   1314.67
# 1 2021-01-21      US  Manhattan   pm25     43  1.0  59.0    21.0   1314.67
# 2 2021-01-21      US  Manhattan   pm25     43  1.0  59.0    21.0   1314.67
# 3 2021-01-21      US  Manhattan   pm25     43  1.0  59.0    21.0   1314.67
# 4 2021-01-21      US      Miami   pm10     54  1.0  32.0     6.0    462.54
#
#         city  ...       lng population  density   source military  \
# 0  Manhattan  ...  -73.9662  1628706.0  27545.0  polygon    False
# 1  Manhattan  ...  -96.6046    57046.0   1062.0  polygon    False
# 2  Manhattan  ...  -87.9805     8240.0    476.0  polygon    False
# 3  Manhattan  ... -111.3343     1906.0    421.0  polygon    False
# 4      Miami  ...  -80.2102  6445545.0   5019.0  polygon    False
#
#    incorporated          timezone  ranking  \
# 0          True  America/New_York      1.0
# 1          True   America/Chicago      3.0
# 2          True   America/Chicago      3.0
# 3          True    America/Denver      3.0
# 4          True  America/New_York      1.0
#
#                                                 zips            id
# 0  10026 10027 10030 10037 10039 10001 10011 1001...  1.840034e+09
# 1                            66506 66502 66503 66505  1.840002e+09
# 2                                              60442  1.840011e+09
# 3                                              59741  1.840022e+09
# 4  33129 33125 33126 33127 33128 33149 33144 3314...  1.840015e+09
#
# [5 rows x 26 columns]

# %%
'''
dropping columns and renaming for clarity before merge
'''
aqicitydrop = ['source', 'military', 'incorporated', 'timezone','lat', 'lng','county_fips', 'Country', 'City', 'ranking', 'zips','id','state_id', 'state_name','city_ascii']
aqi_city = aqi_city.drop(columns= aqicitydrop)
aqi_city = aqi_city.rename(columns={'state_name':'state','county_name':'county'})

# %% [markdown]
# # Merging Covid/Asthma/AQI

# %%
aqi_city
# Out:
#              Date Specie  count  min   max  median  variance        city  \
# 0      2021-01-21   pm25     43  1.0  59.0    21.0   1314.67   Manhattan
# 1      2021-01-21   pm25     43  1.0  59.0    21.0   1314.67   Manhattan
# 2      2021-01-21   pm25     43  1.0  59.0    21.0   1314.67   Manhattan
# 3      2021-01-21   pm25     43  1.0  59.0    21.0   1314.67   Manhattan
# 4      2021-01-21   pm10     54  1.0  32.0     6.0    462.54       Miami
# ...           ...    ...    ...  ...   ...     ...       ...         ...
# 467037 2019-12-30     co     23  1.4   1.9     1.7      0.15     Atlanta
# 467038 2019-12-30     co     23  1.4   1.9     1.7      0.15     Atlanta
# 467039 2019-12-30     co     23  1.4   1.9     1.7      0.15     Atlanta
# 467040 2019-12-30     co     23  1.4   1.9     1.7      0.15     Atlanta
# 467041 2019-12-30     o3     23  4.0  31.2    18.4    526.82  Fort Worth
#
#             county  population  density
# 0         New York   1628706.0  27545.0
# 1            Riley     57046.0   1062.0
# 2             Will      8240.0    476.0
# 3         Gallatin      1906.0    421.0
# 4       Miami-Dade   6445545.0   5019.0
# ...            ...         ...      ...
# 467037       Macon       380.0    428.0
# 467038      Cowley       181.0    146.0
# 467039        Winn       146.0     52.0
# 467040      Phelps       132.0    220.0
# 467041     Tarrant    909585.0   1016.0
#
# [467042 rows x 11 columns]

# %%
master1 = pd.merge(covid_asthma,aqi_city,
    how="left",                      
    left_on = ['county'],
    right_on = ['county']
)
master1
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-26-5c4ef653dbbc> in <module>
#       2     how="left",
#       3     left_on = ['county'],
# ----> 4     right_on = ['county']
#       5 )
#       6 master1
#
# ~/.local/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      87         validate=validate,
#      88     )
# ---> 89     return op.get_result()
#      90
#      91
#
# ~/.local/lib/python3.6/site-packages/pandas/core/reshape/merge.py in get_result(self)
#     666             self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     667
# --> 668         join_index, left_indexer, right_indexer = self._get_join_info()
#     669
#     670         llabels, rlabels = _items_overlap_with_suffix(
#
# ~/.local/lib/python3.6/site-packages/pandas/core/reshape/merge.py in _get_join_info(self)
#     882             )
#     883         else:
# --> 884             (left_indexer, right_indexer) = self._get_join_indexers()
#     885
#     886             if self.right_index:
#
# ~/.local/lib/python3.6/site-packages/pandas/core/reshape/merge.py in _get_join_indexers(self)
#     861         """ return the join indexers """
#     862         return _get_join_indexers(
# --> 863             self.left_join_keys, self.right_join_keys, sort=self.sort, how=self.how
#     864         )
#     865
#
# ~/.local/lib/python3.6/site-packages/pandas/core/reshape/merge.py in _get_join_indexers(left_keys, right_keys, sort, how, **kwargs)
#    1353     }[how]
#    1354
# -> 1355     return join_func(lkey, rkey, count, **kwargs)
#    1356
#    1357
#
# pandas/_libs/join.pyx in pandas._libs.join.left_outer_join()
#
# pandas/_libs/join.pyx in pandas._libs.join._get_result_indexer()
#
# MemoryError: Unable to allocate 5.62 GiB for an array with shape (753807573,) and data type int64

# %% [markdown]
# Ideas on kernel death:
# 1. if joining by state, different cities will be joined together? --> refine to match by city or county instead of state probably by county
#
# 2.  5.62 GiB for array with shape 753807573

# %% [markdown]
# # HistAQI

# %%
# histAQI = pd.read_excel('airqualitytrendsbycity1990-2019.xlsx')
# histAQI.head()

# %%
histAQI_Year_column = pd.melt(histAQI, id_vars=(['Pollutant','StateAbbr','Trend Statistic']), value_vars=([1990,
                                1991,                          1992,
                                1993,                          1994,
                                1995,                          1996,
                                1997,                          1998,
                                1999,                          2000,
                                2001,                          2002,
                                2003,                          2004,
                                2005,                          2006,
                                2007,                          2008,
                                2009,                          2010,
                                2011,                          2012,
                                2013,                          2014,
                                2015,                          2016,
                                2017,                          2018,
                                2019]), var_name='Year', value_name='Pollutant Value').dropna()
histAQI_Year_column.head()

# %%
cities = histAQI['Core Based Statistical Area']
y = [str(i).split() for i in cities]

states = []
for i in y:
    state = i[-1]
    states.append(state)
histAQI['StateAbbr'] = states

# %%
histAQI.head()

# %%
histAQI_asthma= histAQI_asthma[histAQI_asthma.StateAbbr != 'US']

# %%
histAQI_asthma

# %%
#copied code to fill in values from histAQI_asthma
sns.lineplot(x = "Year", y = "Pollutant Value", data = histAQI_Year_column)
plt.title('Total Pollutant Values over Time')
plt.show()

# %%
sns.lineplot(x = "Year", y = "Pollutant Value", data = histAQI_Year_column)
plt.title('Total Pollutant Values over Time')
plt.show()

# %%
sns.lineplot(x = "Year", y = "Pollutant Value", data = histAQI_Year_column, hue = "Pollutant")
plt.title('Pollutant Values over Time')
plt.show()

# %% [markdown]
# # Merge AQI and Asthma

# %%
#append adds rows
# histAQI_asthma = histAQI_Year_column.append(asthma_premerge)

#merge combines
AQI_asthma = pd.merge(asthma1,AQI_big6df,
    how="left",                      
    left_on = ['state'],
    right_on = ['state'])                        
AQI_asthma
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-4e4c04e73587> in <module>
#       6     how="left",
#       7     left_on = ['state'],
# ----> 8     right_on = ['state'])
#       9 AQI_asthma
#
# ~/.local/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      85         copy=copy,
#      86         indicator=indicator,
# ---> 87         validate=validate,
#      88     )
#      89     return op.get_result()
#
# ~/.local/lib/python3.6/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     650             self.right_join_keys,
#     651             self.join_names,
# --> 652         ) = self._get_merge_keys()
#     653
#     654         # validate the merge keys dtypes. We may need to coerce
#
# ~/.local/lib/python3.6/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1003                     if not is_rkey(rk):
#    1004                         if rk is not None:
# -> 1005                             right_keys.append(right._get_label_or_level_values(rk))
#    1006                         else:
#    1007                             # work-around for merge_asof(right_index=True)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1561             values = self.axes[axis].get_level_values(key)._values
#    1562         else:
# -> 1563             raise KeyError(key)
#    1564
#    1565         # Check for duplicates
#
# KeyError: 'state'

# %% [markdown]
# # Demographics

# %%
demographics_data = pd.read_csv("https://data.cdc.gov/resource/vbim-akqf.csv")

# %%
demographics_data.groupby('race_ethnicity_combined').size()

# %%
demographics_data.describe()

# %%
# Out:
#             Date Country             City       Specie  count     min     max  \
# 612567  9/9/2020      US         Hartford         pm10     48    10.0    32.0
# 655525  9/9/2020      US      Springfield           o3     24     1.6    32.8
# 622276  9/9/2020      US          Houston          no2     93     0.3    23.3
# 587151  9/9/2020      US         Portland     pressure    188    29.5  1017.9
# 636160  9/9/2020      US        Charlotte         pm25     47     5.0    59.0
# 611427  9/9/2020      US         Hartford     humidity     48    48.0    91.7
# 703393  9/9/2020      US            Miami    wind-gust     55     0.2    11.0
# 576690  9/9/2020      US           Boston         pm25    133     5.0    65.0
# 622961  9/9/2020      US          Houston     pressure    114  1010.2  1018.0
# 607360  9/9/2020      US        Milwaukee         pm10    119     1.0     8.0
# 606610  9/9/2020      US        Milwaukee          dew     28    10.0    13.0
# 573099  9/9/2020      US          Jackson          no2     22     1.0     9.1
# 765115  9/9/2020      US           Queens           o3     69     0.8    35.2
# 617639  9/9/2020      US          Chicago   wind-speed    206     0.1    10.3
# 723260  9/9/2020      US        San Diego   wind-speed     15     0.2     6.5
# 621816  9/9/2020      US          Houston           o3    118     0.8    38.4
# 641631  9/9/2020      US          Oakland          no2    122     1.9    19.5
# 715396  9/9/2020      US        Las Vegas    wind-gust    148     0.1    20.1
# 718712  9/9/2020      US      San Antonio  temperature    110    17.3    30.5
# 639749  9/9/2020      US       Sacramento     humidity     62    23.6    74.5
# 606558  9/9/2020      US        Milwaukee     pressure    167  1019.8  1032.1
# 727389  9/9/2020      US         Columbus          dew     23    17.0    20.0
# 675778  9/9/2020      US      Little Rock   wind-speed     46     1.5     5.1
# 619253  9/9/2020      US          Chicago  temperature    215     8.6    19.0
# 708818  9/9/2020      US     Jacksonville   wind-speed     67     0.1     4.1
# 735394  9/9/2020      US           Denver  temperature    209    -0.6     8.0
# 766005  9/9/2020      US           Queens     pressure     96  1022.9  1026.7
# 745504  9/9/2020      US      Albuquerque     pressure     72  1010.0  1027.1
# 632196  9/9/2020      US          Atlanta   wind-speed     15     0.1     1.5
# 592796  9/9/2020      US           Austin     humidity     54    86.7    97.0
# ...          ...     ...              ...          ...    ...     ...     ...
# 610186  1/1/2020      US         Hartford         pm25     47     9.0    32.0
# 634897  1/1/2020      US        Charlotte           o3     46     2.4    32.8
# 762507  1/1/2020      US           Tucson          no2     24     2.9    19.3
# 677220  1/1/2020      US        Baltimore          so2      2     1.5     1.5
# 561504  1/1/2020      US    Oklahoma City         pm10     96     4.0    18.0
# 616371  1/1/2020      US  Washington D.C.          so2     23     0.2     0.6
# 656861  1/1/2020      US      Springfield   wind speed      8     2.1     4.0
# 745679  1/1/2020      US    San Francisco          no2     68     1.0    22.3
# 652201  1/1/2020      US         Brooklyn         pm25    168     1.0    54.0
# 568132  1/1/2020      US          Raleigh         pm10     24     2.0    21.0
# 626120  1/1/2020      US     Indianapolis          no2     22     5.6    10.2
# 721224  1/1/2020      US     Philadelphia    wind-gust     22     1.6    10.8
# 593219  1/1/2020      US           Austin         pm25     48     8.0   127.0
# 720255  1/1/2020      US     Philadelphia           co     20     1.2    10.0
# 725437  1/1/2020      US         Columbus         pm25     24     4.0    35.0
# 688433  1/1/2020      US          El Paso           o3    166     0.8    35.2
# 680905  1/1/2020      US          Phoenix         pm10    190     1.0   473.0
# 641618  1/1/2020      US          Oakland          no2    137     1.9    26.0
# 584595  1/1/2020      US         Portland          so2     19     0.3     0.4
# 583440  1/1/2020      US         Richmond   wind-speed      2     0.1     0.8
# 623199  1/1/2020      US          Houston         pm25     72     9.0   381.0
# 702613  1/1/2020      US        Manhattan         pm25     65     1.0    59.0
# 629948  1/1/2020      US          Atlanta    wind-gust     22     0.7     5.7
# 764651  1/1/2020      US           Queens           co     24     1.7     2.4
# 631288  1/1/2020      US          Atlanta          no2     24     2.2    23.2
# 591349  1/1/2020      US            Boise         pm10     22     1.0    10.0
# 658408  1/1/2020      US        The Bronx           o3     22    14.5    19.2
# 605137  1/1/2020      US        Milwaukee          so2     45     0.2     1.5
# 700172  1/1/2020      US        Manhattan           o3     23    14.5    20.8
# 605671  1/1/2020      US        Milwaukee         pm25    166     1.0   117.0
#
#         median   variance
# 612567    14.0     260.83
# 655525     8.8    1401.61
# 622276     6.0     247.76
# 587151  1011.8  922671.00
# 636160    25.0    1317.60
# 611427    73.0    1440.65
# 703393     3.5      64.82
# 576690    30.0    1973.43
# 622961  1013.2      31.09
# 607360     5.0      34.21
# 606610    11.0       9.95
# 573099     2.1      46.07
# 765115    21.6    1273.14
# 617639     3.2      49.36
# 723260     2.2      49.88
# 621816    16.8     746.54
# 641631     8.4     156.09
# 715396    10.0     252.86
# 718712    25.7      68.13
# 639749    39.3    1386.63
# 606558  1025.2      71.10
# 727389    18.0       6.32
# 675778     3.0      13.97
# 619253    16.3      47.82
# 708818     1.0      10.10
# 735394     2.2      52.55
# 766005  1025.3      14.87
# 745504  1021.1     176.70
# 632196     0.4       2.02
# 592796    93.5      90.96
# ...        ...        ...
# 610186    15.0     301.83
# 634897    22.4     910.50
# 762507    10.4     235.31
# 677220     1.5       0.00
# 561504    10.0      64.84
# 616371     0.3       0.22
# 656861     3.3       4.83
# 745679     7.5     346.66
# 652201    30.0    1299.37
# 568132     8.0     219.93
# 626120     7.5      24.86
# 721224     7.7      49.02
# 593219    43.0    6362.98
# 720255     2.3      67.86
# 725437    19.0     709.28
# 688433    23.3    1172.03
# 680905    27.0   59407.60
# 641618    12.1     325.49
# 584595     0.3       0.03
# 583440     0.1       2.45
# 623199    50.0   56428.00
# 702613    27.0    1272.20
# 629948     3.0      23.10
# 764651     2.1       0.34
# 631288     5.6     426.43
# 591349     4.0      69.20
# 658408    16.8      28.12
# 605137     0.3       1.05
# 700172    18.4      44.07
# 605671    28.0    2340.26
#
# [212246 rows x 9 columns]
